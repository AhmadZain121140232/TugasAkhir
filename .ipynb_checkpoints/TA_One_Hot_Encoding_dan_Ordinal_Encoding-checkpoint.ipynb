# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np
import warnings

from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.inspection import permutation_importance

# %% [markdown]
# # Reading Dataset

# %%
"""
data = pd.read_csv("data/heart_attack_prediction_indonesia.csv", keep_default_na=False)
data.head()

data_shuffled = data.sample(frac=1, random_state=42).reset_index(drop=True)
data_reduced = data_shuffled.head(10000)
print(data_reduced.shape)

data_reduced.to_csv('data/data_reduced.csv', index=False)
""";

# %%
data = pd.read_csv("data/data_reduced.csv", keep_default_na=False)
data
# Out:
#       age  gender region income_level  hypertension  diabetes  \
# 0      52  Female  Urban       Middle             0         1
# 1      69    Male  Urban          Low             1         0
# 2      74    Male  Urban       Middle             0         0
# 3      48  Female  Urban       Middle             1         0
# 4      38  Female  Urban          Low             1         0
# ...   ...     ...    ...          ...           ...       ...
# 9995   43    Male  Rural          Low             1         0
# 9996   53  Female  Urban          Low             0         0
# 9997   55    Male  Rural       Middle             0         1
# 9998   59    Male  Rural       Middle             0         0
# 9999   60  Female  Urban          Low             0         0
#
#       cholesterol_level  obesity  waist_circumference  family_history  ...  \
# 0                   217        0                   84               0  ...
# 1                   233        0                  114               0  ...
# 2                   176        0                   57               0  ...
# 3                   143        0                   96               1  ...
# 4                   176        0                   89               1  ...
# ...                 ...      ...                  ...             ...  ...
# 9995                255        1                  110               0  ...
# 9996                115        0                   90               1  ...
# 9997                150        0                   95               1  ...
# 9998                222        0                   80               0  ...
# 9999                168        0                   97               0  ...
#
#      blood_pressure_diastolic fasting_blood_sugar cholesterol_hdl  \
# 0                          67                  70              58
# 1                          68                  90              52
# 2                          90                 137              31
# 3                          79                  81              57
# 4                          79                 136              42
# ...                       ...                 ...             ...
# 9995                       74                 160              50
# 9996                       70                  70              59
# 9997                       83                  94              54
# 9998                       84                 153              60
# 9999                       87                 117              54
#
#      cholesterol_ldl triglycerides EKG_results  previous_heart_disease  \
# 0                125            57    Abnormal                       0
# 1                128           144      Normal                       1
# 2                133           150      Normal                       0
# 3                127           159      Normal                       0
# 4                160           214      Normal                       1
# ...              ...           ...         ...                     ...
# 9995             111           100      Normal                       0
# 9996             146           190      Normal                       1
# 9997             161           101      Normal                       0
# 9998              98           148      Normal                       0
# 9999             117           140    Abnormal                       1
#
#       medication_usage  participated_in_free_screening  heart_attack
# 0                    1                               0             1
# 1                    0                               1             1
# 2                    0                               1             0
# 3                    0                               0             0
# 4                    1                               1             0
# ...                ...                             ...           ...
# 9995                 1                               0             1
# 9996                 1                               1             0
# 9997                 0                               1             0
# 9998                 0                               1             0
# 9999                 1                               1             1
#
# [10000 rows x 28 columns]

# %% [markdown]
# # Manual Mapping for Ordinal Encoding

# %%
ordinal_mappings = {
    'income_level': {'Low': 0, 'Middle': 1, 'High': 2},
    'alcohol_consumption': {'None': 0, 'Moderate': 1, 'High': 2},
    'physical_activity': {'Low': 0, 'Moderate': 1, 'High': 2},
    'dietary_habits': {'Unhealthy': 0, 'Healthy': 1},
    'air_pollution_exposure': {'Low': 0, 'Moderate': 1, 'High': 2},
    'stress_level': {'Low': 0, 'Moderate': 1, 'High': 2},
    'smoking_status': {'Never': 0, 'Past': 1, 'Current': 2},
    'gender': {'Female': 0, 'Male': 1},
    'region': {'Rural': 0, 'Urban': 1},
    'EKG_results': {'Normal': 0, 'Abnormal': 1}
}

# %%
pd.set_option('future.no_silent_downcasting', True)
data_ordinal = data.copy()
data_ordinal.replace(ordinal_mappings, inplace=True)

# %% [markdown]
# # Define Features and Target

# %%
features = ['age', 'gender', 'region', 'income_level', 'hypertension', 'diabetes',
    'cholesterol_level', 'obesity', 'waist_circumference', 'family_history',
    'smoking_status', 'alcohol_consumption', 'physical_activity', 'dietary_habits',
    'air_pollution_exposure', 'stress_level', 'sleep_hours',
    'blood_pressure_systolic', 'blood_pressure_diastolic', 'fasting_blood_sugar',
    'cholesterol_hdl', 'cholesterol_ldl', 'triglycerides', 'EKG_results',
    'medication_usage', 'participated_in_free_screening', 'previous_heart_disease']
target = 'heart_attack'

print(f"Number of Features: {len(features)}")
# Out:
# Number of Features: 27

# %% [markdown]
# # Preprocessing Non-Numerical Features

# %%
categorical_features = ['gender', 'region', 'income_level', 'smoking_status', 'alcohol_consumption', 'physical_activity', 'dietary_habits',
                        'air_pollution_exposure', 'stress_level', 'EKG_results']
numeric_features = [col for col in features if col not in categorical_features]

onehot_transformer = Pipeline(steps=[ 
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

ordinal_transformer = Pipeline(steps=[
    ('ordinal', OrdinalEncoder(categories=[['Low', 'Middle', 'High'], ['None', 'Moderate', 'High'], 
                                            ['Low', 'Moderate', 'High'], ['Unhealthy', 'Healthy'], 
                                            ['Low', 'Moderate', 'High'], ['Low', 'Moderate', 'High'], 
                                            ['Never', 'Past', 'Current'], ['Female', 'Male'], 
                                            ['Rural', 'Urban'], ['Normal', 'Abnormal']], 
                               handle_unknown='use_encoded_value', unknown_value=-1))
])

numeric_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())
])

preprocessor_onehot = ColumnTransformer(
    transformers=[
        ('cat', onehot_transformer, categorical_features),
        ('num', numeric_transformer, numeric_features)  # Apply scaling for numeric features
    ],
    remainder='passthrough'
)

preprocessor_ordinal = ColumnTransformer(
    transformers=[
        ('cat', ordinal_transformer, categorical_features),
        ('num', numeric_transformer, numeric_features)  # Apply scaling for numeric features
    ],
    remainder='passthrough'
)

# %% [markdown]
# # Splitting

# %% [markdown]
# ## Split into X and y

# %%
X = data[features]
y = data[target]

# %% [markdown]
# ## Splitting Data Into 5 Folds

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# %% [markdown]
# # Define Model

# %%
models = {
    'XGB': XGBClassifier(random_state=42),
    'RFC': RandomForestClassifier(random_state=42),
    'GBC': GradientBoostingClassifier(random_state=42),
    'SVC': SVC(random_state=42)
}

results = {model: {'accuracy_onehot': [], 'precision_onehot': [], 'recall_onehot': [], 'f1_onehot': [],
                   'accuracy_ordinal': [], 'precision_ordinal': [], 'recall_ordinal': [], 'f1_ordinal': []}
           for model in models}

# %% [markdown]
# # Training

# %%
for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    for name, model in models.items():
        model_pipeline_onehot = Pipeline(steps=[
            ('preprocessor', preprocessor_onehot),
            ('classifier', model)
        ])
        model_pipeline_onehot.fit(X_train, y_train)
        y_pred_onehot = model_pipeline_onehot.predict(X_test)

        model_pipeline_ordinal = Pipeline(steps=[
            ('preprocessor', preprocessor_ordinal),
            ('classifier', model)
        ])
        model_pipeline_ordinal.fit(X_train, y_train)
        y_pred_ordinal = model_pipeline_ordinal.predict(X_test)

        # Simpan skor
        results[name]['accuracy_onehot'].append(accuracy_score(y_test, y_pred_onehot))
        results[name]['precision_onehot'].append(precision_score(y_test, y_pred_onehot))
        results[name]['recall_onehot'].append(recall_score(y_test, y_pred_onehot))
        results[name]['f1_onehot'].append(f1_score(y_test, y_pred_onehot))

        results[name]['accuracy_ordinal'].append(accuracy_score(y_test, y_pred_ordinal))
        results[name]['precision_ordinal'].append(precision_score(y_test, y_pred_ordinal))
        results[name]['recall_ordinal'].append(recall_score(y_test, y_pred_ordinal))
        results[name]['f1_ordinal'].append(f1_score(y_test, y_pred_ordinal))

# %% [markdown]
# # Get Feature Importance

# %%
def get_feature_importance(model, model_name, X, y):
    try:
        # Jika preprocessor ada di pipeline
        preprocessor = model.named_steps['preprocessor']
        if isinstance(preprocessor, ColumnTransformer):
            feature_names = []
            for name, transformer, cols in preprocessor.transformers_:
                if name == 'cat':
                    # Ambil nama fitur dari OneHotEncoder
                    encoder = transformer.named_steps['onehot'] if isinstance(transformer, Pipeline) else transformer
                    feature_names.extend(encoder.get_feature_names_out(cols))
                elif name == 'num':
                    feature_names.extend(cols)
                else:
                    pass
        else:
            feature_names = X.columns.tolist()
    except:
        feature_names = X.columns.tolist()

    classifier = model.named_steps['classifier']

    if model_name == 'SVC':
        if hasattr(classifier, 'kernel') and classifier.kernel == 'linear':
            importances = classifier.coef_[0]
            feature_importance = dict(zip(feature_names, importances))
        else:
            result = permutation_importance(model, X, y, n_repeats=10, random_state=42, n_jobs=-1)
            feature_importance = dict(zip(feature_names, result.importances_mean))
    elif model_name in ['XGB', 'RFC', 'GBC']:
        importances = classifier.feature_importances_
        feature_importance = dict(zip(feature_names, importances))
    else:
        return None

    return dict(sorted(feature_importance.items(), key=lambda item: abs(item[1]), reverse=True))

# %% [markdown]
# # Evaluate Model

# %%
for name, scores in results.items():
    print(f"\nModel: {name}")
    print(f"OneHot Encoding:")
    print(f"Accuracy:  {np.mean(scores['accuracy_onehot'])*100:.4f}%")
    print(f"Precision: {np.mean(scores['precision_onehot'])*100:.4f}%")
    print(f"Recall:    {np.mean(scores['recall_onehot'])*100:.4f}%")
    print(f"F1 Score:  {np.mean(scores['f1_onehot'])*100:.4f}%")

    print(f"\nOrdinal Encoding:")
    print(f"Accuracy:  {np.mean(scores['accuracy_ordinal'])*100:.4f}%")
    print(f"Precision: {np.mean(scores['precision_ordinal'])*100:.4f}%")
    print(f"Recall:    {np.mean(scores['recall_ordinal'])*100:.4f}%")
    print(f"F1 Score:  {np.mean(scores['f1_ordinal'])*100:.4f}%")

    print(f"\nFeature Importance for {name} (OneHot Encoding):")
    final_pipeline_onehot = Pipeline(steps=[
        ('preprocessor', preprocessor_onehot),
        ('classifier', models[name])
    ])
    final_pipeline_onehot.fit(X, y)
    importance_onehot = get_feature_importance(final_pipeline_onehot, name, X, y)
    
    if importance_onehot:
        for feature, value in importance_onehot.items():
            print(f"{feature}: {value:.10f}")

    print(f"\nFeature Importance for {name} (Ordinal Encoding):")
    final_pipeline = Pipeline(steps=[
        ('preprocessor', preprocessor_ordinal),
        ('classifier', models[name])
    ])
    final_pipeline.fit(X, y)
    importance = get_feature_importance(final_pipeline, name, X, y)
    if importance:
        for feature, value in importance.items():
            print(f"{feature}: {value:.10f}")
# Out:
# Model: XGB
# OneHot Encoding:
# Accuracy:  71.3400%
# Precision: 65.8847%
# Recall:    61.9236%
# F1 Score:  63.8406%
#
# Ordinal Encoding:
# Accuracy:  69.9500%
# Precision: 64.4090%
# Recall:    59.0796%
# F1 Score:  61.6178%
#
# Feature Importance for XGB (OneHot Encoding):
# previous_heart_disease: 0.1620469987
# hypertension: 0.1383284479
# smoking_status_Current: 0.0837775841
# diabetes: 0.0744486004
# obesity: 0.0660088360
# age: 0.0199503787
# cholesterol_level: 0.0189168137
# fasting_blood_sugar: 0.0170733221
# physical_activity_Low: 0.0160311516
# stress_level_Moderate: 0.0158394836
# gender_Female: 0.0156696942
# income_level_High: 0.0148363393
# alcohol_consumption_High: 0.0147222066
# income_level_Middle: 0.0146717420
# stress_level_High: 0.0143414820
# family_history: 0.0142588252
# triglycerides: 0.0141625460
# physical_activity_High: 0.0139251053
# cholesterol_ldl: 0.0138709005
# region_Rural: 0.0138302827
# dietary_habits_Healthy: 0.0138263088
# blood_pressure_diastolic: 0.0137808267
# air_pollution_exposure_Low: 0.0137780337
# sleep_hours: 0.0136596663
# blood_pressure_systolic: 0.0134972958
# physical_activity_Moderate: 0.0134764519
# air_pollution_exposure_High: 0.0134442272
# EKG_results_Abnormal: 0.0134050399
# waist_circumference: 0.0133260293
# alcohol_consumption_None: 0.0132825384
# smoking_status_Past: 0.0132547077
# income_level_Low: 0.0132144019
# alcohol_consumption_Moderate: 0.0131675806
# cholesterol_hdl: 0.0131282676
# smoking_status_Never: 0.0120681031
# medication_usage: 0.0119921360
# participated_in_free_screening: 0.0112492908
# stress_level_Low: 0.0109500736
# air_pollution_exposure_Moderate: 0.0087882467
# gender_Male: 0.0000000000
# region_Urban: 0.0000000000
# dietary_habits_Unhealthy: 0.0000000000
# EKG_results_Normal: 0.0000000000
#
# Feature Importance for XGB (Ordinal Encoding):
# alcohol_consumption: 0.2499072552
# previous_heart_disease: 0.2162176967
# physical_activity: 0.1010818183
# air_pollution_exposure: 0.0910568163
# smoking_status: 0.0291501693
# cholesterol_hdl: 0.0247416422
# dietary_habits: 0.0240666680
# diabetes: 0.0202209894
# cholesterol_ldl: 0.0199990086
# triglycerides: 0.0199563541
# EKG_results: 0.0196641404
# region: 0.0195765849
# fasting_blood_sugar: 0.0194303691
# stress_level: 0.0194263048
# blood_pressure_systolic: 0.0193641987
# hypertension: 0.0190321561
# blood_pressure_diastolic: 0.0188078806
# medication_usage: 0.0176913477
# family_history: 0.0173380096
# participated_in_free_screening: 0.0170121882
# sleep_hours: 0.0162584055
# age: 0.0000000000
# gender: 0.0000000000
# income_level: 0.0000000000
# cholesterol_level: 0.0000000000
# obesity: 0.0000000000
# waist_circumference: 0.0000000000
#
# Model: RFC
# OneHot Encoding:
# Accuracy:  72.5200%
# Precision: 69.6918%
# Recall:    58.0454%
# F1 Score:  63.3108%
#
# Ordinal Encoding:
# Accuracy:  71.4000%
# Precision: 67.6936%
# Recall:    57.4328%
# F1 Score:  62.1415%
#
# Feature Importance for RFC (OneHot Encoding):
# cholesterol_level: 0.0673830874
# hypertension: 0.0657229091
# age: 0.0638492618
# previous_heart_disease: 0.0621262405
# fasting_blood_sugar: 0.0583080295
# sleep_hours: 0.0561910292
# cholesterol_ldl: 0.0544563519
# triglycerides: 0.0537898282
# blood_pressure_systolic: 0.0530462990
# waist_circumference: 0.0528336745
# blood_pressure_diastolic: 0.0494359616
# cholesterol_hdl: 0.0488642579
# diabetes: 0.0321945428
# smoking_status_Current: 0.0270467889
# obesity: 0.0255003824
# smoking_status_Never: 0.0102735396
# participated_in_free_screening: 0.0101690590
# medication_usage: 0.0101018425
# family_history: 0.0094284918
# stress_level_Moderate: 0.0089883253
# alcohol_consumption_None: 0.0089613956
# physical_activity_Moderate: 0.0088503426
# income_level_Middle: 0.0087905677
# physical_activity_Low: 0.0087653491
# air_pollution_exposure_Moderate: 0.0086129671
# income_level_Low: 0.0085894959
# stress_level_High: 0.0084007094
# alcohol_consumption_Moderate: 0.0083872657
# gender_Female: 0.0083373070
# gender_Male: 0.0082813427
# air_pollution_exposure_Low: 0.0081285999
# dietary_habits_Healthy: 0.0081122566
# region_Rural: 0.0079563003
# region_Urban: 0.0079388226
# dietary_habits_Unhealthy: 0.0077516663
# smoking_status_Past: 0.0076456082
# air_pollution_exposure_High: 0.0074743561
# stress_level_Low: 0.0071800854
# physical_activity_High: 0.0070535000
# EKG_results_Normal: 0.0066739135
# income_level_High: 0.0066311530
# EKG_results_Abnormal: 0.0062597375
# alcohol_consumption_High: 0.0055073550
#
# Feature Importance for RFC (Ordinal Encoding):
# dietary_habits: 0.0839455728
# smoking_status: 0.0775879927
# cholesterol_hdl: 0.0732431413
# alcohol_consumption: 0.0718849565
# blood_pressure_systolic: 0.0714083820
# previous_heart_disease: 0.0685990594
# triglycerides: 0.0684777539
# EKG_results: 0.0682036468
# stress_level: 0.0660530387
# blood_pressure_diastolic: 0.0634358774
# fasting_blood_sugar: 0.0627352311
# cholesterol_ldl: 0.0616007640
# physical_activity: 0.0358937979
# air_pollution_exposure: 0.0273689563
# diabetes: 0.0195175095
# region: 0.0190308840
# hypertension: 0.0170680928
# participated_in_free_screening: 0.0118928242
# medication_usage: 0.0118649918
# sleep_hours: 0.0109679047
# family_history: 0.0092196220
# age: 0.0000000000
# gender: 0.0000000000
# income_level: 0.0000000000
# cholesterol_level: 0.0000000000
# obesity: 0.0000000000
# waist_circumference: 0.0000000000
#
# Model: GBC
# OneHot Encoding:
# Accuracy:  73.5900%
# Precision: 69.6278%
# Recall:    62.7344%
# F1 Score:  66.0001%
#
# Ordinal Encoding:
# Accuracy:  72.1800%
# Precision: 68.0640%
# Recall:    60.1774%
# F1 Score:  63.8731%
#
# Feature Importance for GBC (OneHot Encoding):
# hypertension: 0.2254497339
# previous_heart_disease: 0.2245774335
# diabetes: 0.1174573339
# smoking_status_Current: 0.1153614568
# obesity: 0.0891514976
# age: 0.0688711020
# cholesterol_level: 0.0598403427
# fasting_blood_sugar: 0.0404554421
# cholesterol_ldl: 0.0107754626
# cholesterol_hdl: 0.0082461011
# waist_circumference: 0.0078055617
# sleep_hours: 0.0078021718
# triglycerides: 0.0060337369
# blood_pressure_diastolic: 0.0056914126
# blood_pressure_systolic: 0.0048671788
# dietary_habits_Unhealthy: 0.0011383806
# dietary_habits_Healthy: 0.0009948095
# stress_level_Moderate: 0.0007362480
# physical_activity_High: 0.0006170503
# income_level_High: 0.0005846664
# alcohol_consumption_None: 0.0005157964
# stress_level_High: 0.0005149989
# air_pollution_exposure_High: 0.0005053632
# physical_activity_Low: 0.0004387249
# air_pollution_exposure_Low: 0.0003814492
# income_level_Middle: 0.0003347674
# physical_activity_Moderate: 0.0002789583
# air_pollution_exposure_Moderate: 0.0002377332
# smoking_status_Past: 0.0002022978
# alcohol_consumption_High: 0.0001327879
# gender_Female: 0.0000000000
# gender_Male: 0.0000000000
# region_Rural: 0.0000000000
# region_Urban: 0.0000000000
# income_level_Low: 0.0000000000
# smoking_status_Never: 0.0000000000
# alcohol_consumption_Moderate: 0.0000000000
# stress_level_Low: 0.0000000000
# EKG_results_Abnormal: 0.0000000000
# EKG_results_Normal: 0.0000000000
# family_history: 0.0000000000
# medication_usage: 0.0000000000
# participated_in_free_screening: 0.0000000000
#
# Feature Importance for GBC (Ordinal Encoding):
# previous_heart_disease: 0.2533994395
# alcohol_consumption: 0.2521845986
# physical_activity: 0.1293978794
# air_pollution_exposure: 0.0980016032
# smoking_status: 0.0773293301
# dietary_habits: 0.0687244548
# cholesterol_hdl: 0.0500746872
# cholesterol_ldl: 0.0131223451
# triglycerides: 0.0124959908
# stress_level: 0.0101958432
# fasting_blood_sugar: 0.0087329647
# EKG_results: 0.0079863530
# blood_pressure_systolic: 0.0074390894
# blood_pressure_diastolic: 0.0036646461
# diabetes: 0.0030242920
# hypertension: 0.0017831466
# region: 0.0011987204
# sleep_hours: 0.0009037631
# family_history: 0.0002517318
# medication_usage: 0.0000891209
# age: 0.0000000000
# gender: 0.0000000000
# income_level: 0.0000000000
# cholesterol_level: 0.0000000000
# obesity: 0.0000000000
# waist_circumference: 0.0000000000
# participated_in_free_screening: 0.0000000000
#
# Model: SVC
# OneHot Encoding:
# Accuracy:  72.6400%
# Precision: 68.6519%
# Recall:    60.8029%
# F1 Score:  64.4879%
#
# Ordinal Encoding:
# Accuracy:  70.9700%
# Precision: 67.6659%
# Recall:    55.6083%
# F1 Score:  61.0244%
#
# Feature Importance for SVC (OneHot Encoding):
# income_level_High: 0.0821700000
# age: 0.0815200000
# smoking_status_Current: 0.0415200000
# income_level_Low: 0.0409100000
# alcohol_consumption_High: 0.0396100000
# gender_Female: 0.0185000000
# income_level_Middle: 0.0175500000
# air_pollution_exposure_Low: 0.0133700000
# smoking_status_Past: 0.0120500000
# EKG_results_Abnormal: 0.0093400000
# EKG_results_Normal: 0.0091000000
# air_pollution_exposure_Moderate: 0.0090600000
# smoking_status_Never: 0.0089700000
# stress_level_High: 0.0087400000
# stress_level_Low: 0.0085700000
# dietary_habits_Healthy: 0.0085000000
# air_pollution_exposure_High: 0.0084600000
# dietary_habits_Unhealthy: 0.0082200000
# physical_activity_Moderate: 0.0073500000
# physical_activity_Low: 0.0071600000
# alcohol_consumption_None: 0.0070900000
# alcohol_consumption_Moderate: 0.0070700000
# region_Rural: 0.0056000000
# gender_Male: 0.0055500000
# region_Urban: 0.0055400000
# physical_activity_High: 0.0054200000
# stress_level_Moderate: 0.0045900000
#
# Feature Importance for SVC (Ordinal Encoding):
# previous_heart_disease: 0.0823700000
# hypertension: 0.0656000000
# diabetes: 0.0358800000
# obesity: 0.0307800000
# cholesterol_level: 0.0131500000
# age: 0.0129300000
# fasting_blood_sugar: 0.0092000000
# waist_circumference: 0.0086100000
# sleep_hours: 0.0079300000
# cholesterol_ldl: 0.0076900000
# triglycerides: 0.0072900000
# blood_pressure_diastolic: 0.0070400000
# participated_in_free_screening: 0.0067300000
# cholesterol_hdl: 0.0065900000
# family_history: 0.0064000000
# alcohol_consumption: 0.0063300000
# physical_activity: 0.0061400000
# medication_usage: 0.0059900000
# blood_pressure_systolic: 0.0055200000
# income_level: 0.0052000000
# EKG_results: 0.0023500000
# gender: 0.0000000000
# region: 0.0000000000
# smoking_status: 0.0000000000
# dietary_habits: 0.0000000000
# air_pollution_exposure: 0.0000000000
# stress_level: 0.0000000000
