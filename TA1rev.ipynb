# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np
import warnings

from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.inspection import permutation_importance

# %% [markdown]
# # Reading Dataset

# %%
"""
data = pd.read_csv("data/heart_attack_prediction_indonesia.csv", keep_default_na=False)
data.head()

data_shuffled = data.sample(frac=1, random_state=42).reset_index(drop=True)
data_reduced = data_shuffled.head(10000)
print(data_reduced.shape)

data_reduced.to_csv('data/data_reduced.csv', index=False)
""";

# %%
data = pd.read_csv("data/data_reduced.csv", keep_default_na=False)
data
# Out:
#       age  gender region income_level  hypertension  diabetes  \
# 0      52  Female  Urban       Middle             0         1
# 1      69    Male  Urban          Low             1         0
# 2      74    Male  Urban       Middle             0         0
# 3      48  Female  Urban       Middle             1         0
# 4      38  Female  Urban          Low             1         0
# ...   ...     ...    ...          ...           ...       ...
# 9995   43    Male  Rural          Low             1         0
# 9996   53  Female  Urban          Low             0         0
# 9997   55    Male  Rural       Middle             0         1
# 9998   59    Male  Rural       Middle             0         0
# 9999   60  Female  Urban          Low             0         0
#
#       cholesterol_level  obesity  waist_circumference  family_history  ...  \
# 0                   217        0                   84               0  ...
# 1                   233        0                  114               0  ...
# 2                   176        0                   57               0  ...
# 3                   143        0                   96               1  ...
# 4                   176        0                   89               1  ...
# ...                 ...      ...                  ...             ...  ...
# 9995                255        1                  110               0  ...
# 9996                115        0                   90               1  ...
# 9997                150        0                   95               1  ...
# 9998                222        0                   80               0  ...
# 9999                168        0                   97               0  ...
#
#      blood_pressure_diastolic fasting_blood_sugar cholesterol_hdl  \
# 0                          67                  70              58
# 1                          68                  90              52
# 2                          90                 137              31
# 3                          79                  81              57
# 4                          79                 136              42
# ...                       ...                 ...             ...
# 9995                       74                 160              50
# 9996                       70                  70              59
# 9997                       83                  94              54
# 9998                       84                 153              60
# 9999                       87                 117              54
#
#      cholesterol_ldl triglycerides EKG_results  previous_heart_disease  \
# 0                125            57    Abnormal                       0
# 1                128           144      Normal                       1
# 2                133           150      Normal                       0
# 3                127           159      Normal                       0
# 4                160           214      Normal                       1
# ...              ...           ...         ...                     ...
# 9995             111           100      Normal                       0
# 9996             146           190      Normal                       1
# 9997             161           101      Normal                       0
# 9998              98           148      Normal                       0
# 9999             117           140    Abnormal                       1
#
#       medication_usage  participated_in_free_screening  heart_attack
# 0                    1                               0             1
# 1                    0                               1             1
# 2                    0                               1             0
# 3                    0                               0             0
# 4                    1                               1             0
# ...                ...                             ...           ...
# 9995                 1                               0             1
# 9996                 1                               1             0
# 9997                 0                               1             0
# 9998                 0                               1             0
# 9999                 1                               1             1
#
# [10000 rows x 28 columns]

# %% [markdown]
# # Define Features and Target

# %%
features = ['age', 'gender', 'region', 'income_level', 'hypertension', 'diabetes',
    'cholesterol_level', 'obesity', 'waist_circumference', 'family_history',
    'smoking_status', 'alcohol_consumption', 'physical_activity', 'dietary_habits',
    'air_pollution_exposure', 'stress_level', 'sleep_hours',
    'blood_pressure_systolic', 'blood_pressure_diastolic', 'fasting_blood_sugar',
    'cholesterol_hdl', 'cholesterol_ldl', 'triglycerides', 'EKG_results',
    'medication_usage', 'participated_in_free_screening', 'previous_heart_disease']
target = 'heart_attack'

print(f"Number of Features: {len(features)}")
# Out:
# Number of Features: 27

# %% [markdown]
# # Preprocessing Non-Numerical Features

# %%
categorical_features = ['gender', 'region', 'income_level', 'smoking_status', 'alcohol_consumption', 'physical_activity', 'dietary_habits',
                        'air_pollution_exposure', 'stress_level', 'EKG_results']
numeric_features = [col for col in features if col not in categorical_features]

categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])
numeric_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())
])

preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, categorical_features)
    ],
    remainder='passthrough'
)
svc_preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, categorical_features),
        ('num', numeric_transformer, numeric_features)
    ]
)

# %% [markdown]
# # Splitting Data Into 5 Folds

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# %% [markdown]
# # Define Model

# %%
models = {
    'XGB': Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('classifier', XGBClassifier(random_state=42))
    ]),
    'RFC': Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('classifier', RandomForestClassifier(random_state=42))
    ]),
    'GBC': Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('classifier', GradientBoostingClassifier(random_state=42))
    ]),
    'SVC': Pipeline(steps=[
        ('preprocessor', svc_preprocessor),
        ('classifier', SVC(random_state=42))
    ])
}

results = {model: {'accuracy': [],'precision': [],'recall': [],'f1': []} for model in models}

# %% [markdown]
# # Training

# %%
for train_index, test_index in kf.split(data[features]):
    X_train, X_test = data[features].iloc[train_index], data[features].iloc[test_index]
    y_train, y_test = data[target].iloc[train_index], data[target].iloc[test_index]
    
    for name, model in models.items():
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)

        results[name]['accuracy'].append(accuracy_score(y_test, y_pred))
        results[name]['precision'].append(precision_score(y_test, y_pred))
        results[name]['recall'].append(recall_score(y_test, y_pred))
        results[name]['f1'].append(f1_score(y_test, y_pred))

warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# # Evaluate Model

# %%
for name, scores in results.items():
    print(f"\nModel: {name}")
    print(f"Accuracy:  {np.mean(scores['accuracy'])*100:.4f}%")
    print(f"Precision: {np.mean(scores['precision'])*100:.4f}%")
    print(f"Recall:    {np.mean(scores['recall'])*100:.4f}%")
    print(f"F1 Score:  {np.mean(scores['f1'])*100:.4f}%")
# Out:
# Model: XGB
# Accuracy:  71.3400%
# Precision: 65.8847%
# Recall:    61.9236%
# F1 Score:  63.8406%
#
# Model: RFC
# Accuracy:  72.5100%
# Precision: 69.6552%
# Recall:    58.0710%
# F1 Score:  63.3135%
#
# Model: GBC
# Accuracy:  73.5900%
# Precision: 69.6278%
# Recall:    62.7344%
# F1 Score:  66.0001%
#
# Model: SVC
# Accuracy:  72.6400%
# Precision: 68.6519%
# Recall:    60.8029%
# F1 Score:  64.4879%

# %% [markdown]
# # Check Feature Importance

# %%
def get_feature_importance(model, model_name, X, y):
    feature_names = model.named_steps['preprocessor'].get_feature_names_out()

    if model_name == 'XGB':
        importances = model.named_steps['classifier'].feature_importances_
    elif model_name == 'RFC':
        importances = model.named_steps['classifier'].feature_importances_
    elif model_name == 'GBC':
        importances = model.named_steps['classifier'].feature_importances_
    elif model_name == 'SVC':
        perm_importance = permutation_importance(model, X, y, n_repeats=3, random_state=42)
        importances = perm_importance.importances_mean
    else:
        return None

    feature_importance = dict(zip(feature_names, importances))
    
    return dict(sorted(feature_importance.items(), key=lambda item: abs(item[1]), reverse=True))

# %%
X = data[features]
y = data[target]

for name, model in models.items():
    print(f"\nFeature Importance for {name}:")
    importance = get_feature_importance(model, name, X, y)
    if importance:
        for feature, value in importance.items():
            print(f"{feature}: {value}")
    print()
# Out:
# Feature Importance for XGB:
# remainder__previous_heart_disease: 0.14246341586112976
# remainder__hypertension: 0.1413353532552719
# remainder__diabetes: 0.07951324433088303
# cat__smoking_status_Current: 0.0750470981001854
# remainder__obesity: 0.06057510897517204
# remainder__age: 0.02210092917084694
# cat__alcohol_consumption_High: 0.020117957144975662
# remainder__cholesterol_level: 0.019334951415657997
# remainder__fasting_blood_sugar: 0.018457522615790367
# cat__EKG_results_Abnormal: 0.01784081943333149
# cat__physical_activity_High: 0.01620306633412838
# cat__smoking_status_Past: 0.01608036458492279
# cat__physical_activity_Low: 0.016031891107559204
# cat__region_Rural: 0.015810443088412285
# remainder__cholesterol_hdl: 0.015507325530052185
# remainder__waist_circumference: 0.015462658368051052
# remainder__triglycerides: 0.015316380187869072
# cat__alcohol_consumption_None: 0.015276569873094559
# remainder__cholesterol_ldl: 0.015145831741392612
# cat__dietary_habits_Healthy: 0.015134856104850769
# cat__stress_level_Low: 0.014939215034246445
# cat__air_pollution_exposure_Low: 0.014825153164565563
# remainder__blood_pressure_systolic: 0.01458846777677536
# cat__income_level_High: 0.014477292075753212
# remainder__sleep_hours: 0.014456138014793396
# remainder__blood_pressure_diastolic: 0.014420691877603531
# cat__income_level_Low: 0.014361285604536533
# remainder__medication_usage: 0.014006765559315681
# cat__gender_Female: 0.01385938934981823
# remainder__participated_in_free_screening: 0.013229495845735073
# remainder__family_history: 0.012963542714715004
# cat__smoking_status_Never: 0.012508051469922066
# cat__stress_level_Moderate: 0.011950201354920864
# cat__air_pollution_exposure_Moderate: 0.0117950439453125
# cat__alcohol_consumption_Moderate: 0.011786142364144325
# cat__air_pollution_exposure_High: 0.011502990499138832
# cat__physical_activity_Moderate: 0.011209809221327305
# cat__income_level_Middle: 0.010859140194952488
# cat__stress_level_High: 0.009505554102361202
# cat__gender_Male: 0.0
# cat__region_Urban: 0.0
# cat__dietary_habits_Unhealthy: 0.0
# cat__EKG_results_Normal: 0.0
#
#
# Feature Importance for RFC:
# remainder__cholesterol_level: 0.0685684100200572
# remainder__hypertension: 0.06514587621495206
# remainder__age: 0.06270117887756962
# remainder__previous_heart_disease: 0.06264079940470114
# remainder__fasting_blood_sugar: 0.060699189504273714
# remainder__cholesterol_ldl: 0.05478677656013201
# remainder__sleep_hours: 0.05439842756681282
# remainder__triglycerides: 0.05435950059049751
# remainder__waist_circumference: 0.05301636809107234
# remainder__blood_pressure_systolic: 0.05141840122405699
# remainder__cholesterol_hdl: 0.049070594611682256
# remainder__blood_pressure_diastolic: 0.04891835447121586
# remainder__diabetes: 0.032198967722202716
# cat__smoking_status_Current: 0.02756774607825871
# remainder__obesity: 0.023849840449879596
# cat__smoking_status_Never: 0.01118477606875221
# remainder__medication_usage: 0.009599473042730771
# remainder__participated_in_free_screening: 0.009581168959918614
# remainder__family_history: 0.00921799581137876
# cat__stress_level_Moderate: 0.008961706476458985
# cat__alcohol_consumption_None: 0.008864039117391535
# cat__air_pollution_exposure_Moderate: 0.00885712756609483
# cat__physical_activity_Low: 0.008764951019528486
# cat__physical_activity_Moderate: 0.008723260346228603
# cat__stress_level_High: 0.008672688352584909
# cat__smoking_status_Past: 0.008597381510441074
# cat__income_level_Middle: 0.008537328090487944
# cat__income_level_Low: 0.00853322023057313
# cat__gender_Male: 0.008315218479276708
# cat__region_Rural: 0.008277147231158704
# cat__dietary_habits_Unhealthy: 0.008241733451277967
# cat__gender_Female: 0.008186117946204264
# cat__air_pollution_exposure_Low: 0.008150996003337189
# cat__alcohol_consumption_Moderate: 0.008081942951311935
# cat__region_Urban: 0.00804767851206511
# cat__dietary_habits_Healthy: 0.007909528106298825
# cat__income_level_High: 0.0074143483776847
# cat__air_pollution_exposure_High: 0.007353721876206767
# cat__stress_level_Low: 0.007274609288164957
# cat__physical_activity_High: 0.006782718187819261
# cat__EKG_results_Abnormal: 0.006677153977184262
# cat__EKG_results_Normal: 0.006442783860610571
# cat__alcohol_consumption_High: 0.005408753771464516
#
#
# Feature Importance for GBC:
# remainder__previous_heart_disease: 0.21898331611137214
# remainder__hypertension: 0.2166309119746984
# cat__smoking_status_Current: 0.11783972530534481
# remainder__diabetes: 0.11133583934580098
# remainder__obesity: 0.08339843784407337
# remainder__cholesterol_level: 0.06888289660401849
# remainder__age: 0.06822126976501902
# remainder__fasting_blood_sugar: 0.044024571257485184
# remainder__cholesterol_ldl: 0.012730437643067978
# remainder__waist_circumference: 0.009678847807086785
# remainder__sleep_hours: 0.009495716148630132
# remainder__blood_pressure_diastolic: 0.007960919448044331
# remainder__cholesterol_hdl: 0.0069783591317207575
# remainder__triglycerides: 0.006055809979375466
# remainder__blood_pressure_systolic: 0.0049637854699190785
# cat__physical_activity_Low: 0.0019801911977888977
# cat__physical_activity_High: 0.0014510564511747354
# cat__air_pollution_exposure_Low: 0.0011300045116390894
# cat__dietary_habits_Unhealthy: 0.0008970384159955327
# cat__income_level_High: 0.000777745031162448
# cat__gender_Female: 0.0007417669642490724
# cat__stress_level_Low: 0.0007403535773053175
# cat__income_level_Middle: 0.0006994158285098741
# cat__smoking_status_Never: 0.0006653810584397406
# cat__air_pollution_exposure_High: 0.0006549484185886488
# cat__dietary_habits_Healthy: 0.0006373730318415433
# cat__alcohol_consumption_None: 0.000632035879760661
# cat__gender_Male: 0.0005833919404163132
# cat__alcohol_consumption_High: 0.00038330786336665084
# cat__physical_activity_Moderate: 0.00027917517094962506
# cat__smoking_status_Past: 0.0002519620314497381
# cat__region_Rural: 0.00016199578044041407
# cat__region_Urban: 0.00015201301126475817
# cat__income_level_Low: 0.0
# cat__alcohol_consumption_Moderate: 0.0
# cat__air_pollution_exposure_Moderate: 0.0
# cat__stress_level_High: 0.0
# cat__stress_level_Moderate: 0.0
# cat__EKG_results_Abnormal: 0.0
# cat__EKG_results_Normal: 0.0
# remainder__family_history: 0.0
# remainder__medication_usage: 0.0
# remainder__participated_in_free_screening: 0.0
#
#
# Feature Importance for SVC:
